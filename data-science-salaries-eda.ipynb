# %% [markdown]
# <a href="https://www.kaggle.com/code/bahaakhaled97/data-science-salaries-eda?scriptVersionId=108545372" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahaakhalled/Data-Science-Salaries-EDA/blob/main/data_science_salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="background-color:lightblue;font-family:newtimeroman;color:white;font-size:170%;text-align:center;border-radius:40px 60px;">Data Science Salaries: EDA</p>
# <div style="width:100%;text-align: left;"> <img align=middle src="https://imageio.forbes.com/specials-images/imageserve/615a844b0e678d9d11c5fc26/The-5-Biggest-Data-Science-Trends-In-2022/960x0.jpg?format=jpg&width=960" alt="Heat beating" style="width:1000px;height:500px;margin-top:3rem;"> </div>
#
#
#
# **<span style="color:Blue;"> Data Science Salaries </span>** Data Science Salaries vary from different country to position to years of experience and more, The dataset holds data on various data scientists with difference in various features mentioned in details below. The purpose of my work was to give an overview of the highest and lowest paid salaries in this field according to all aspects of a company.

# %% [markdown]
# # <p style="background-color:lightblue;font-family:newtimeroman;color:white;text-align:center;font-size:120%;border-radius:20px 60px;">Table Of Contents</p>
# * **Importing Library**
# * **Loading data**
# * **Data Visualization**

# %% [markdown]
# # <p style="background-color:lightblue;font-family:newtimeroman;color:white;text-align:center;font-size:120%;border-radius:20px 40px;">Importing Libraries</p>

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %% [markdown]
# # <p style="background-color:lightblue;font-family:newtimeroman;color:white;text-align:center;font-size:120%;border-radius:20px 40px;">Loading Data</p>
# **About the data:**
#
# * This dataset contains 10 features which are the most impactful features with a persons salary in general
#
# * work_year: Details are collected over three years starting 2020 to 2022
#
# * Experience Level: The seniority of the person based on years of experience in the field, this data is in form of titles EN Entry-level / Junior MI Mid-level / Intermediate SE Senior-level / Expert EX Executive-level / Director
#
# * employment_type: The type of employement for the role: PT Part-time FT Full-time CT Contract FL Freelance
#
# * job_title: The role worked in during the year.
#
# * salary: The total gross salary amount paid.
#
# * salary_currency: The currency of the salary paid as an ISO 4217 currency code.
#
# * salaryinusd: The salary in USD (FX rate divided by avg. USD rate for the respective year via fxdata.foorilla.com).
#
# * employee_residence: Employee's primary country of residence in during the work year as an ISO 3166 country code.
#
# * remote_ratio: The overall amount of work done remotely, possible values are as follows: 0 No remote work (less than 20%) 50 Partially remote 100 Fully remote (more than 80%)
#
# * company_location: The country of the employer's main office or contracting branch as an ISO 3166 country code.
#
# * company_size: The average number of people that worked for the company during the year: S less than 50 employees (small) M 50 to 250 employees (medium) L more than 250 employees (large)
#
# Note: Dataset details are from data scource found [here](https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries).

# %%
my_file = Path("ds_salaries.csv")
if my_file.is_file()==False:
  # !wget 'https://raw.githubusercontent.com/Bahaakhalled/Data-Science-Salaries-EDA/main/ds_salaries.csv'
# Out:
# --2022-10-19 11:24:22--  https://raw.githubusercontent.com/Bahaakhalled/Data-Science-Salaries-EDA/main/ds_salaries.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36960 (36K) [text/plain]
# Saving to: ‘ds_salaries.csv’
#
# ds_salaries.csv     100%[===================>]  36.09K  --.-KB/s    in 0.004s
#
# 2022-10-19 11:24:22 (8.60 MB/s) - ‘ds_salaries.csv’ saved [36960/36960]

# %%
ds_salaries=pd.read_csv('ds_salaries.csv')
ds_salaries.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
ds_salaries.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %% [markdown]
# # <p style="background-color:lightblue;font-family:newtimeroman;color:white;text-align:center;font-size:120%;border-radius:20px 40px;">Data Visualization</p>

# %%
ds_salaries.hist(figsize=(25,12))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'work_year'}>],
#        [<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'salary_in_usd'}>],
#        [<AxesSubplot:title={'center':'remote_ratio'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
dsc=ds_salaries.copy()
dsc=dsc.drop('Unnamed: 0',axis=1)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.lineplot(data = dsc,x="work_year",y="salary_in_usd",hue = "experience_level").set(title='Yearly Salary based on experience level\n')
# Out:
# [Text(0.5, 1.0, 'Yearly Salary based on experience level\n')]

# %% [markdown]
# * The Plot above shows rise in salaries based on experience level over the years and we see that salaries only slightly increased in difference exp level in 2022 and has decreased in Executive titles from last year

# %%
figure, axis = plt.subplots(1, 4,figsize=(25,12))

axis[0].set_title('Remote Ratio Distribution')
dsc.remote_ratio.value_counts().plot.pie(ax=axis[0])

axis[1].set_title('Employment Type Distribution')
dsc.employment_type.value_counts().plot.pie(ax=axis[1])

axis[2].set_title('Experience LevelDistribution')
dsc.experience_level.value_counts().plot.pie(ax=axis[2])

axis[3].set_title('Company Size Distribution')
dsc.company_size.value_counts().plot.pie(ax=axis[3])
# Out:
# <AxesSubplot:title={'center':'Company Size Distribution'}, ylabel='company_size'>

# %% [markdown]
# **Pie Chart insights:**
# * Most work since the pandemic or atleast 2020 tended to favor a higher remote ratio than before and mostly agree with full time remote rather than a 50:50 or 0 remote ratio
# * Most Employment types are on full time basis
# * This data shows more Senior level employees followed by mid levels,entry and executives
# * Most Company sizes are Medium followed by Large and lastly small

# %%
figure, axis = plt.subplots(1, 2,figsize=(25,9))

dsc.groupby('company_size').salary_in_usd.mean().plot(kind='bar',ax=axis[0])
axis[0].set_title('Salary Average based on Company Size')


dsc.groupby('company_location').salary_in_usd.mean().sort_values(ascending=False).head(20).plot(kind='bar',ax=axis[1])
axis[1].set_title('Salary Average based on Company Location')
# Out:
# Text(0.5, 1.0, 'Salary Average based on Company Location')

# %% [markdown]
# **Bar Chart insights:**
# * The bigger the company size the higher the salary
# * Russia,USA, New Zealand have the top Average Salary

# %%
dsc.groupby('job_title').salary_in_usd.agg(['mean','count']).sort_values(by=['mean','count'],ascending=False).head(7)
# Out:
#                                    mean  count
# job_title
# Data Analytics Lead       405000.000000      1
# Principal Data Engineer   328333.333333      3
# Financial Data Analyst    275000.000000      2
# Principal Data Scientist  215242.428571      7
# Director of Data Science  195074.000000      7
# Data Architect            177873.909091     11
# Applied Data Scientist    175655.000000      5

# %%
dsc.nunique()
# Out:
# work_year               3
# experience_level        4
# employment_type         4
# job_title              50
# salary                272
# salary_currency        17
# salary_in_usd         369
# employee_residence     57
# remote_ratio            3
# company_location       50
# company_size            3
# dtype: int64

# %%
dsc.company_location.value_counts().head(15)
# Out:
# US    355
# GB     47
# CA     30
# DE     28
# IN     24
# FR     15
# ES     14
# GR     11
# JP      6
# NL      4
# AT      4
# PT      4
# PL      4
# LU      3
# PK      3
# Name: company_location, dtype: int64

# %% [markdown]
# * Most of the Data are from US Jobs

# %%
figure, axis = plt.subplots(1, 3,figsize=(25,12))

dsc.loc[dsc.company_size=='L'].company_location.value_counts().plot.pie(ax=axis[0])
axis[0].set_title('Large Company Locations')

dsc.loc[dsc.company_size=='M'].company_location.value_counts().plot.pie(ax=axis[1])
axis[1].set_title('Medium Company Locations')

dsc.loc[dsc.company_size=='S'].company_location.value_counts().plot.pie(ax=axis[2])
axis[2].set_title('Small Company Locations')
# Out:
# Text(0.5, 1.0, 'Small Company Locations')

# %% [markdown]
# **Since most of the data are from Companies based in the US**
# * India is the Second country with Large Companies
# * The United Kingdom comes Second in Medium Size Companies
# * Germany,Japan,UK and India come after the US in small sized Companies

# %%
dsc.groupby('job_title').work_year.count().sort_values(ascending=False).head(10)
# Out:
# job_title
# Data Scientist                143
# Data Engineer                 132
# Data Analyst                   97
# Machine Learning Engineer      41
# Research Scientist             16
# Data Science Manager           12
# Data Architect                 11
# Big Data Engineer               8
# Machine Learning Scientist      8
# Director of Data Science        7
# Name: work_year, dtype: int64

# %%
figure, axis = plt.subplots(1, 3,figsize=(25,7))

dsc.loc[dsc['job_title']=='Data Scientist'].groupby('company_location').salary_in_usd.mean().sort_values(ascending=False).head(5).plot(ax=axis[0])

dsc.loc[dsc['job_title']=='Data Engineer'].groupby('company_location').salary_in_usd.mean().sort_values(ascending=False).head(5).plot(ax=axis[1])

dsc.loc[dsc['job_title']=='Data Analyst'].groupby('company_location').salary_in_usd.mean().sort_values(ascending=False).head(5).plot(ax=axis[2])
# Out:
# <AxesSubplot:xlabel='company_location'>

# %% [markdown]
# * Average Salary in USD based on Company Location for the titles Data Science,Data Engineer and Data Analyst Respectively

# %%
figure, axis = plt.subplots(1, 3,figsize=(25,7))

dsc.loc[dsc['job_title']=='Data Scientist'].groupby('work_year').salary_in_usd.mean().plot(kind='bar',ax=axis[0])

dsc.loc[dsc['job_title']=='Data Engineer'].groupby('work_year').salary_in_usd.mean().plot(kind='bar',ax=axis[1])

dsc.loc[dsc['job_title']=='Data Analyst'].groupby('work_year').salary_in_usd.mean().plot(kind='bar',ax=axis[2])
# Out:
# <AxesSubplot:xlabel='work_year'>

# %% [markdown]
# **The average salary for the same titles from the years 2020-2022 we see:**
# * Data Scientists now earn yearly on average 135k which is 58% higher than the average salaries in 2020
# * Data Engineers now earn 44% more than in 2020
# * Data Analysts now earn 122% more than the year 2020

# %%
dsc.groupby('experience_level').sum()
# Out:
#                   work_year     salary  salary_in_usd  remote_ratio
# experience_level
# EN                   177849   23286776        5424612          6150
# EX                    52557   11103875        5184193          2050
# MI                   430532  102371568       18743160         13600
# SE                   566055   59905819       38812842         21250

# %% [markdown]
# * Remote Ratio is more common in Senior Levels followed by Mid,Entry and lastly Executive Level
